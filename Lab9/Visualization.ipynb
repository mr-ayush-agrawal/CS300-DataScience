# %% [markdown]
# Q 8

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

pop = pd.read_csv('pop.csv',index_col=0)
tab = pop.pivot_table(columns='country', index='year', values='population')
tab.head()

plt.plot(tab['China'], c='r',label = 'China')
plt.plot(tab['United States'], c='b',label = 'United States')
plt.plot(tab['India'], c='orange',label = 'India')
plt.xlabel("Years")
plt.ylabel("Population in Billions")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# e:\CourseCode\CS3006-DataScience\Lab9\Visualization.ipynb Cell 2 line 5
#       <a href='vscode-notebook-cell:/e%3A/CourseCode/CS3006-DataScience/Lab9/Visualization.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> import seaborn as sns
#       <a href='vscode-notebook-cell:/e%3A/CourseCode/CS3006-DataScience/Lab9/Visualization.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/e%3A/CourseCode/CS3006-DataScience/Lab9/Visualization.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> pop = pd.read_csv('pop.csv',index_col=0)
#       <a href='vscode-notebook-cell:/e%3A/CourseCode/CS3006-DataScience/Lab9/Visualization.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> tab = pop.pivot_table(columns='country', index='year', values='population')
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

pop = pd.read_csv('iris.csv',index_col=0)
data_corr = pop.corr()
data_corr

sns.heatmap(data_corr, cmap='Greens', annot= True)
# Out:
# <Axes: >

# %%
from keyboard import write
from time import sleep
a = '''
import seaborn as sns
import pandas as pd

pop = pd.read_csv('iris.csv',index_col=0)
data_corr = pop.corr()
data_corr

sns.heatmap(data_corr, cmap='Greens', annot= True)
'''

sleep(1)
write(a)
